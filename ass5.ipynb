# %% [markdown]
# # 스크립트 프로그래밍 ass5

# %% [markdown]
# # 2014.12.12

# %% [markdown]
# # 2012136091 이슬

# %% [markdown]
# #### [1번 문제] 클래스와 모듈의 공통점과 차이점에 대해 설명하시오.

# %% [markdown]
# 공통점 : 모듈은 파이썬 프로그램 파일로써 파이썬 데이터와 함수 등을 정의하고있는 단위인데 파이썬 클래스는 새로운 이름 공간을 지원하는 또다른 단위이다.

# %% [markdown]
# 차이점 : 모듈은 파일단위로 이름공간을 구성하고 클래스는 클래스 영역 내에 이름공간을 구성한다.

# %% [markdown]
# #### [2번 문제] 다형성에 대해 설명하고 다형성을 보여주는 자신만의 파이썬 코드 예제를 제시하시오.

# %% [markdown]
# 다형성이란 상속관계 내의 다른 클래스들의 인스턴스들이 같은 멤버함수 호출에 대해 각각 다르게 반응하도록 하는 기능이다. 장점은 하나의 이름으로 다양한 객체들에게 유사한 작업을 수행시킬 수 있고 프로그램 작성 코드 량이 줄어들고 코드의 가독성을 높혀주는 것이 있다. 단점은 형 선언이 없다.

# %%
class Student: 
    def gpa(self): 
        print '...' 

class Freshman(Student): 
    def gpa(self): 
        print '1.0' 

class Sophomore(Student): 
    def gpa(self): 
        print '2.0' 

class Junior(Student): 
    def gpa(self): 
        print '3.0' 

class Senior(Student): 
    pass 

for each in (Freshman(), Sophomore(), Junior(), Senior()): 
        each.gpa()
# Out:
# 1.0
# 2.0
# 3.0
# ...

# %% [markdown]
# [3번 문제] 다음 각 요구사항 모두를 만족시키는 Counter 클래스를 코딩하시오 (정답을 각 요구사항별로 입력할 필요 없이 3번 문제에 대해 1개의 클래스 정의 코드를 제시하면 된다.)

# %%
class Counter:
    def __init__(self, count=0, step=1):
        if count==None:
            count=0
        self.count=count
        self.step=step
    def incr(self):
        self.count+=self.step
    def __str__(self) :
        return "[Count(Step:"+str(self.step)+")]"+str(self.count)
    def __call__(self):
        self.count+=self.step
        return self.count
    def __add__(self, num):
        self.count+=num
        return self
    def __sub__(self, num):
        self.count-=num
        return self
    def __cmp__(self, num2):
        return self.count-num2
    
c=Counter(10)
d=Counter(10,2)

print c
print d
# Out:
# [Count(Step:1)]10
# [Count(Step:2)]10

# %%
c.incr()
d.incr()
print c
print d
# Out:
# [Count(Step:1)]11
# [Count(Step:2)]12

# %%
c()
d()
print c
print d
# Out:
# [Count(Step:1)]12
# [Count(Step:2)]14

# %%
c=c+5
d=d-5
print c
print d
# Out:
# [Count(Step:1)]17
# [Count(Step:2)]9

# %%
print c>10
print d>10
print c<10
print d<10
print c==17
print d!=9
# Out:
# True
# False
# False
# True
# True
# False

# %% [markdown]
# [4번 문제] 다음은 내장 자료형 list를 서브클래싱하여 만든 MySet 클래스 정의 내용이다. 다음 클래스 정의에서 __init__(), __str()__(), elimicate_duplicate()의 세 개의 메소드 코드 내용을 자신이 다른 사람에게 가르친다고 생각하며 설명해보시오.

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print s
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print t
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}

# %% [markdown]
# init에서 eliminate_duplicate로 값을 받은 후 리스트 s에 중복 없이 저장한다. 그 다음에 다시 l에 저장하는데 이것은 self의 중복을 제거한다. str은 결과를 출력한다.

# %% [markdown]
# [5번 문제] 4번 문제에 정의된 MySet 클래스에 메소드를 추가하여 다음 각 요구사항 모두를 만족시키는 코딩을 제시하시오 (정답을 각 요구사항별로 입력할 필요 없이 5번 문제에 대해 1개의 MySet 클래스 정의 코드를 제시하면 된다.)

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)            
    def __or__(self, x) :
        for e in x:
            if e not in self:
                self.append(e)
        return self
    def __and__(self, x) :
        s = []
        for e in x:
            for a in self:
                if e == a :
                    s.append(e)
        self[:] = []
        for e in s:
            self.append(e)
        return self   
    def __sub__(self, x) :
        for a in self:
            for b in x :
                if a == b :
                    self.remove(a)
        return self
                

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print s
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print t
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}

# %%
s = s|t
print s
# Out:
# MySet: {1 ,2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}

# %%
s = MySet([1,2,3])
t = MySet([3,4,5])
s = s & t
print s
# Out:
# MySet: {3}

# %%
s = MySet([1,2,3])
t = MySet([3,4,5])
s = s - t
print s
# Out:
# MySet: {1 ,2}

# %% [markdown]
# [6번 문제] 5번 문제에서 정의한 MySet 클래스에 대해 다음 예제를 수행하면 오류없이 올바르게 동작하는 것을 확인할 수 있다. 다음 예제 내에 있는 len(), bool() 내장함수와 in 키워드 사용 예제가 별다른 메소드 정의를 하지 않았는 데도 올바르게 수행되는 이유를 설명하시오.

# %%
s=MySet([1,2,3,4,5,6])
print len(s)
print bool(s)
print 2 in s
# Out:
# 6
# True
# True

# %% [markdown]
# MySet클래스는 list를 상속받아서 len, bool, in이 올바르게 수행된다.

# %% [markdown]
# [7번 문제] 이전 Assignment 3 (Assignment 4가 아님)의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하여 각 단어들에 대해 출현빈도를 사전형태({'world': 2, 'hello': 1, 'python': 1})로 저장하여 출력하는 것이었다. 이번에는 Assignment 3과 Assignment 4를 확장/변형하여 다음과 같은 조건을 만족하도록 구현하시오.

# %%
import urllib
import string


class WebWordsFrequency :
    def __init__(self, *args) :
        self.l = []
        for e in args :
            self.l.append(e)
            
    def addUrl(self, url) :
        self.l.append(url)
        
    def removeUrl(self, url) :
        self.l.remove(url)
    
    def listUrls(self) :
        for e in self.l :
            print e
            
    def getWordsFrequency(self) :
        self.s = {}
        for e in self.l :
            source = urllib.urlopen(e).read()
    
            len_source = len(source)
            
            source_new = None
            i = 0
            while (i < len_source):
               	found = False
               	if (found != True and source[i] == "<" and source[i+1 : i+7].lower() == "script"):
              		found = True;
              		j = i + 7;
              		while (True):
             			if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+8].lower() == "script"):
                				source = source[:i] + ' ' + source[j+9:]
                				break
             			j = j + 1
             			if (j > len_source):
                				break
              		len_source = len(source)
               	i = i + 1
                
            len_source = len(source)
                
            i = 0
            while (i < len_source):
               	found = False
               	if (found != True and source[i] == "<" and source[i+1 : i+6].lower() == "style"):
              		found = True;
              		j = i + 6;
              		while (True):
             			if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+7].lower() == "style"):
                				source = source[:i] + ' ' + source[j+8:]
                				break
             			j = j + 1
             			if (j > len_source):
                				break
              		len_source = len(source)
               	i = i + 1
            
            len_source = len(source)
            
            i = 0
            while (i < len_source):
               	found = False
               	if (found != True and source[i] == "<"):
              		found = True;
              		j = i + 1;
              		while (True):
             			if (source[j] == ">"):
                				source = source[:i] + ' ' + source[j+1:]
                				break
             			j = j + 1
             			if (j > len_source):
                				break
              		len_source = len(source)
           	i = i + 1
            
            len_source = len(source)
            words = source.split()
            
            w = []
            for word in words:
                i = word.strip(string.punctuation)
                if(len(i)):
                    w.append(i)
            
            D = {}
            
            for word in w:
                if word in D.keys():
                    D[word] += 1
                else:
                    D[word] = 1
            self.s.update(D)
        for x, y in self.s.items() :
            print x, y, '/',
    
    def getMaxFrequencyWords(self) :
        max = 0
        for x, y in self.s.items() :
            if max < y :
                max = y
        
        print "most frequency words : "
        for x, y in self.s.items() :
            if max == y :
                print x
        
w1 = WebWordsFrequency('http://www.daum.net', 'http://www.naver.com', 'http://www.google.co.kr') 
w2 = WebWordsFrequency('http://www.daum.net', 'http://www.naver.com') 
w3 = WebWordsFrequency() 

w1.addUrl('http://cse.koreatech.ac.kr')
w3.addUrl('http://www.koreatech.ac.kr')

w1.removeUrl('http://www.daum.net')
w2.removeUrl('http://www.naver.com')

w1.listUrls()
# Out:
# http://www.naver.com
# http://www.google.co.kr
# http://cse.koreatech.ac.kr

# %%
w1.getWordsFrequency()
w2.getWordsFrequency()
w3.getWordsFrequency()
# Out:
# 현대 1 / gt 1 / 컴퓨터시스템응용 1 / ���α׷� 1 / 한글캠페인 1 / 레이어 5 / 3위 1 / 몬스터뱅 1 / 투기장 1 / 위하여 1 / 뚝 1 / 나눔글꼴이 2 / 7.3 1 / 7.0 3 / 로그인 3 / 사랑의 1 / 6위 1 / ���� 1 / 39;대항해시대&#39 1 / 무한던전 1 / ���� 1 / 지역 2 / 황창규 1 / 검거 1 / 나눔글꼴을 2 / 선호주제설정 1 / N드라이브 1 / ������ 1 / ���� 1 / 영웅의 1 / 연구실소개 1 / 볼 1 / 한채영 2 / 2014-09-24 1 / 클릭하세요 1 / 모집요강 1 / 선물 1 / 별자리 1 / 2012/09/09 1 / 모바일 1 / 스포츠 2 / 제대로 1 / �α��� 1 /
 / NEWS 5 / LOGIN 2 / 학교운영 1 / 총동문회 2 / 교육중심 2 / UNIVERSITY 1 / 재)S&T장학재단]2015년도 1 / 사실에 4 / 2차 1 / 주요메뉴 1 / IT융합과학경영대학원 1 / 동계 1 / 생활관자치회 1 / 도서관이용안내 1 / 더불어 1 / 인크루트 1 / 취업역량강화(동영상 2 / IPP센터 5 / 에너지신소재화학공학부 1 / 있습니다 1 / 캠퍼스사진 4 / 인터넷 1 / 팝업존 1 / 온라인교육 1 / 이용안내 1 / 1위 3 / 제3기 1 / 잡코리아 1 / 총동아리연합회 1 / 천안시 1 / youtube 2 / 법인이사장 1 / 대학홍보 4 / 진로선택과 1 / NO.1 1 / naver 2 / 대학민국 1 / 웹갤러리 1 / 이전 3 / 한기대발전기금 2 / 스크립트를 1 /

# %%
w1.getMaxFrequencyWords()
w2.getMaxFrequencyWords()
w3.getMaxFrequencyWords()
# Out:
# most frequency words :
# ℃
# most frequency words :
# 전
# most frequency words :
# KOREATECH

# %% [markdown]
# [8번 문제] 7번 문제에서 정의한 WebWordsFrequency 클래스를 상속하여 OrderedWebWordsFrequency 클래스를 정의하고 슈퍼클래스에 정의된 getWordsFrequency() 메소드를 오버라이드 하여 단어 출현 빈도를 내림 차순으로 정렬하여 리스트로 출력하시오.

# %%
import urllib
import string


class WebWordsFrequency :
    def __init__(self, *args) :
        self.l = []
        for e in args :
            self.l.append(e)
            
    def addUrl(self, url) :
        self.l.append(url)
        
    def removeUrl(self, url) :
        self.l.remove(url)
    
    def listUrls(self) :
        for e in self.l :
            print e
            
    def getWordsFrequency(self) :
        self.s = {}
        for e in self.l :
            source = urllib.urlopen(e).read()
    
            len_source = len(source)
            
            source_new = None
            i = 0
            while (i < len_source):
               	found = False
               	if (found != True and source[i] == "<" and source[i+1 : i+7].lower() == "script"):
              		found = True;
              		j = i + 7;
              		while (True):
             			if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+8].lower() == "script"):
                				source = source[:i] + ' ' + source[j+9:]
                				break
             			j = j + 1
             			if (j > len_source):
                				break
              		len_source = len(source)
               	i = i + 1
                
            len_source = len(source)
                
            i = 0
            while (i < len_source):
               	found = False
               	if (found != True and source[i] == "<" and source[i+1 : i+6].lower() == "style"):
              		found = True;
              		j = i + 6;
              		while (True):
             			if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+7].lower() == "style"):
                				source = source[:i] + ' ' + source[j+8:]
                				break
             			j = j + 1
             			if (j > len_source):
                				break
              		len_source = len(source)
               	i = i + 1
            
            len_source = len(source)
            
            i = 0
            while (i < len_source):
               	found = False
               	if (found != True and source[i] == "<"):
              		found = True;
              		j = i + 1;
              		while (True):
             			if (source[j] == ">"):
                				source = source[:i] + ' ' + source[j+1:]
                				break
             			j = j + 1
             			if (j > len_source):
                				break
              		len_source = len(source)
           	i = i + 1
            
            len_source = len(source)
            words = source.split()
            
            w = []
            for word in words:
                i = word.strip(string.punctuation)
                if(len(i)):
                    w.append(i)
            
            D = {}
            
            for word in w:
                if word in D.keys():
                    D[word] += 1
                else:
                    D[word] = 1
            self.s.update(D)
        for x, y in self.s.items() :
            print x, y, '/',
    
    def getMaxFrequencyWords(self) :
        max = 0
        for x, y in self.s.items() :
            if max < y :
                max = y
        
        print "most frequency words : "
        for x, y in self.s.items() :
            if max == y :
                print x
                

class OrderedWebWordsFrequency(WebWordsFrequency) :
    def getWordsFrequency(self) :
        self.s = {}
        for e in self.l :
            source = urllib.urlopen(e).read()
    
            len_source = len(source)
            
            source_new = None
            i = 0
            while (i < len_source):
               	found = False
               	if (found != True and source[i] == "<" and source[i+1 : i+7].lower() == "script"):
              		found = True;
              		j = i + 7;
              		while (True):
             			if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+8].lower() == "script"):
                				#print "found - script"
                				source = source[:i] + ' ' + source[j+9:]
                				break
             			j = j + 1
             			if (j > len_source):
                				break
              		len_source = len(source)
               	i = i + 1
                
            len_source = len(source)
                
            i = 0
            while (i < len_source):
               	found = False
               	if (found != True and source[i] == "<" and source[i+1 : i+6].lower() == "style"):
              		found = True;
              		j = i + 6;
              		while (True):
             			if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+7].lower() == "style"):
                				#print "found - style"
                				source = source[:i] + ' ' + source[j+8:]
                				break
             			j = j + 1
             			if (j > len_source):
                				break
              		len_source = len(source)
               	i = i + 1
            
            len_source = len(source)
            
            i = 0
            while (i < len_source):
               	found = False
               	if (found != True and source[i] == "<"):
              		found = True;
              		j = i + 1;
              		while (True):
             			if (source[j] == ">"):
                				source = source[:i] + ' ' + source[j+1:]
                				break
             			j = j + 1
             			if (j > len_source):
                				break
              		len_source = len(source)
           	i = i + 1
            
            len_source = len(source)
            words = source.split()
            
            w = []
            for word in words:
                i = word.strip(string.punctuation)
                if(len(i)):
                    w.append(i)
            
            D = {}
            
            for word in w:
                if word in D.keys():
                    D[word] += 1
                else:
                    D[word] = 1
            self.s.update(D)
        def mycmp(a1, a2) :
            return cmp(a1[1], a2[1])       
        for x, y in sorted(self.s.items(),cmp = mycmp, reverse = True) :
            print '('+str(x)+','+str(y)+')'

# %%
w4 = OrderedWebWordsFrequency('http://www.daum.net', 'http://www.naver.com', 'http://www.google.co.kr')
w4.listUrls()
w4.getWordsFrequency()
w4.getMaxFrequencyWords()
# Out:
# http://www.daum.net
# http://www.naver.com
# http://www.google.co.kr
# (입니다,22)
# (제목,22)
# (링크를,22)
# (내용을,22)
# (확인하시려면,22)
# (전,22)
# (눌러주세요,22)
# (가져오기,22)
# (네이버,16)
# (페이지,15)
# (상승,13)
# (자동완성,10)
# (검색어,10)
# (탭,10)
# (내,8)
# (정보,8)
# (나눔글꼴,8)
# (총,7)
# (책,7)
# (도움말,7)
# (끄기,7)
# (검색어저장,6)
# (켜기,5)
# (닫기,5)
# (1,5)
# (오늘의,5)
# (8,5)
# (바로가기,5)
# (블로그,5)
# (기능이,5)
# (레이어,4)
# (신고,4)
# (설치,4)
# (있습니다,4)
# (txt,4)
# (삭제,4)
# (날씨,4)
# (보기,4)
# (영화,4)
# (홈,3)
# (앱,3)
# (희망해,3)
# (Daum,3)
# (다음앱,3)
# (Google,3)
# (기록,3)
# (스페셜,3)
# (더,3)
# (이벤트,3)
# (검은사막,3)
# (미즈넷,3)
# (뮤직,3)
# (RPG,3)
# (링크모음,3)
# (광고,3)
# (신문,3)
# (상품,3)
# (손석희,3)
# (팁,3)
# (아고라,3)
# (코리아,3)
# (및,3)
# (원,3)
# (포토,3)
# (사이트,3)
# (5,3)
# (꺼져,3)
# (로그인,3)
# (나눔글꼴이,2)
# (정책,2)
# (나눔글꼴을,2)
# (볼,2)
# (한채영,2)
# (관련,2)
# (먹는,2)
# (없습니다,2)
# (자주,2)
# (전문보기,2)
# (주요언론사,2)
# (전일대비,2)
# (부동산,2)
# (사용,2)
# (37,2)
# (주요,2)
# (타임스퀘어,2)
# (다음페이지,2)
# (유병재,2)
# (뉴스,2)
# (황선,2)
# (검색어를,2)
# (나눔글꼴로,2)
# (메뉴,2)
# (재밌는,2)
# (231,2)
# (글꼴설정,2)
# (아이디,2)
# (141,2)
# (콜렉션,2)
# (라이센스,2)
# (지식iN,2)
# (운세,2)
# (26,2)
# (28,2)
# (카페,2)
# (황보,2)
# (게임,2)
# (큐넷,2)
# (문규현,2)
# (89,2)
# (NAVER,2)
# (G마켓,2)
# (경제,2)
# (줄,2)
# (비밀번호,2)
# (7,2)
# (244,2)
# (가능합니다,2)
# (쇼핑,2)
# (경기,2)
# (지도,2)
# (보세요,2)
# (보온,2)
# (문자받기,2)
# (블랙프,2)
# (웹툰,2)
# (모든,2)
# (전체,2)
# (인기,2)
# (몬테네그로,2)
# (사전,2)
# (대한항공,2)
# (2.4℃,2)
# (0.0℃,2)
# (1위,2)
# (신은미,2)
# (대입,2)
# (tv팟,2)
# (메인을,2)
# (히터,2)
# (지역,2)
# (않습니다,2)
# (찾기,2)
# (현재,2)
# (3,2)
# (다시,2)
# (검색,2)
# (수,2)
# (11번가,2)
# (개인,2)
# (위한,2)
# (이전페이지,2)
# (다음,2)
# (전체언론사,2)
# (다운로드URL,2)
# (키즈짱,2)
# (다운로드,2)
# (울언니,2)
# (무료로,2)
# (뉴스스탠드,2)
# (팔달산,2)
# (등록,2)
# (유익한,2)
# (서비스,2)
# (더보기,2)
# (이슈,2)
# (확인되지,2)
# (유로파리그,2)
# (취소,2)
# (IP보안,2)
# (기업을,2)
# (포함,2)
# (무료,2)
# (기능을,2)
# (6,2)
# (저장,2)
# (안내,2)
# (설치하시겠습니까,2)
# (스포츠,2)
# (쇼핑캐스트,2)
# (피노키오,2)
# (사용자가,2)
# (40,2)
# (최근검색어,2)
# (이전,2)
# (옥션,2)
# (오늘만,1)
# (한글캠페인,1)
# (전월세,1)
# (위하여,1)
# (아시나요,1)
# (사랑의,1)
# (네이버캐스트,1)
# (한국인이라서,1)
# (유지,1)
# (����,1)
# (인증샷,1)
# (선호주제설정,1)
# (75,000,1)
# (������,1)
# (고교생&quot;다치게,1)
# (클릭하세요,1)
# (러시아의,1)
# (잇다,1)
# (제대로,1)
# (배송혜택,1)
# (아름답게,1)
# (Now,1)
# (그대로,1)
# (다음캐쉬,1)
# (시스템글꼴,1)
# (����ϴ�,1)
# (Google.com,1)
# (맛은,1)
# (기존,1)
# (방송/통신,1)
# (1.7℃,1)
# (고객센터,1)
# (주제형캐스트,1)
# (대해,1)
# (때는,1)
# (39;호랑이,1)
# (어른의,1)
# (제공되지,1)
# (http://nv1.ad.naver.com/adshow?unit=002AN&nrefreshx=0,1)
# (체험학습,1)
# (현암사,1)
# (전시,1)
# (올해의,1)
# (사우디의,1)
# (����,1)
# (네이버뉴스,1)
# (았던,1)
# (UD온라인,1)
# (출산,1)
# (파리,1)
# (하나부터,1)
# (위,1)
# (CJ몰,1)
# (자동차,1)
# (종합/경제,1)
# (부산,1)
# (�ٿ�ε�,1)
# (완료되지,1)
# (뒤엔,1)
# (읽는,1)
# (용품,1)
# (베스트셀러&nbsp,1)
# (탕퓌,1)
# (찾는,1)
# (첫구매,1)
# (하프클럽,1)
# (new,1)
# (알,1)
# (시장,1)
# (다양해,1)
# (한게임,1)
# (입력하신,1)
# (정체,1)
# (폰트를,1)
# (http://nv2.ad.naver.com/adshow?unit=002AP&nrefreshx=0,1)
# (�α���,1)
# (탐나는,1)
# (설치미술가,1)
# (����̺�,1)
# (카테고리,1)
# (105,1)
# (시공전쟁,1)
# (모멸감,1)
# (확인,1)
# (본인확인,1)
# (빛깔들&hellip;&#39,1)
# (이용을,1)
# (않고,1)
# (롯백오픈축하,1)
# (역사적,1)
# (랠리,1)
# (추천,1)
# (직접,1)
# (자랑스러운,1)
# (경우에,1)
# (일상의,1)
# (0.4℃,1)
# (어떨까,1)
# (추락사..보상도,1)
# (인화물질,1)
# (http://static.nid.naver.com/loginbox.nhn,1)
# (교감하다,1)
# (Chrome,1)
# (광고안내,1)
# (정도면,1)
# (언급에,1)
# (연예,1)
# (가능,1)
# (만남,1)
# (소방서&#39,1)
# (용어사전,1)
# (라이프,1)
# (ㅋ-ㅎ,1)
# (개인정보,1)
# (종료,1)
# (대구,1)
# (목록,1)
# (인물,1)
# (기준금리,1)
# (귀족의,1)
# (미리,1)
# (디앤샵,1)
# (차림의,1)
# (none,1)
# (마지막,1)
# (어수룩,1)
# (캠페인,1)
# (건강,1)
# (열기,1)
# (8위,1)
# (제휴문의,1)
# (북스,1)
# (폰번호,1)
# (동남구,1)
# (여성들,1)
# (비극,1)
# (추정,1)
# (저장되지,1)
# (코디,1)
# (전송은,1)
# (7위,1)
# (6.3℃,1)
# (quot;기레기&quot,1)
# (금,1)
# (237,1)
# (상한제,1)
# (나만의,1)
# (과연,1)
# (아껴주는,1)
# (AK몰,1)
# (말한다,1)
# (���α׷�,1)
# (명소,1)
# (한국의,1)
# (39;모든,1)
# (증권,1)
# (반드시,1)
# (���,1)
# (영자지,1)
# (백령도,1)
# (밀레대박저렴,1)
# (외,1)
# (관리소,1)
# (열것&quot,1)
# (준비하라,1)
# (128,000,1)
# (먹거리,1)
# (tv팟홈,1)
# (무협,1)
# (39;나홀로,1)
# (날짜,1)
# (대장정을,1)
# (달리기,1)
# (를,1)
# (맛본,1)
# (1인4역,1)
# (검색어는,1)
# (3040대추천,1)
# (202.0,1)
# (생각한대로,1)
# (소녀,1)
# (4754.74,1)
# (투표하러가자,1)
# (현위치,1)
# (추가하시려면,1)
# (부산의,1)
# (실시간,1)
# (자세히보기,1)
# (���ͳ���,1)
# (공지사항,1)
# (9위,1)
# (너무나예쁜옷,1)
# (전주,1)
# (39;쉽게,1)
# (의도,1)
# (삶,1)
# (강추위따뜻옷,1)
# (쇼핑몰,1)
# (주요뉴스를,1)
# (2014,1)
# (ndash,1)
# (눈칫밥,1)
# (로드뷰,1)
# (넘치는,1)
# (단독,1)
# (10대,1)
# (나만,1)
# (않는,1)
# (시작페이지로,1)
# (크게,1)
# (질문형,1)
# (매거진/전문지,1)
# (도서관들,1)
# (서울지하철,1)
# (챙겨주는,1)
# (균열이,1)
# (6위,1)
# (없어&quot,1)
# (신세계몰,1)
# (루리웹,1)
# (����,1)
# (매력,1)
# (아빠&#39;가,1)
# (70.72,1)
# (고려하는,1)
# (청소년유해매체물,1)
# (고전과,1)
# (작품과,1)
# (빠른,1)
# (바라보는,1)
# (버튼을,1)
# (FUN,1)
# (예술의,1)
# (발끝에,1)
# (산타는,1)
# (괜찮아요,1)
# (네이버를,1)
# (증시,1)
# (39;무한도전&#39;의,1)
# (평양에,1)
# (내PC,1)
# (회원가입,1)
# (영하,1)
# (쇼핑도움,1)
# (재설치,1)
# (잔스포츠가방,1)
# (�̹���,1)
# (하리수,1)
# (유혹,1)
# (싼&#39,1)
# (IT,1)
# (지워주세요,1)
# (두,1)
# (풀기..양적완화,1)
# (이메일,1)
# (일출,1)
# (내또래,1)
# (직원,1)
# (웹문서,1)
# (유형,1)
# (유력,1)
# (수사본부,1)
# (SSG.com,1)
# (인기기획전,1)
# (times,1)
# (MY뉴스,1)
# (총정리,1)
# (전문자료,1)
# (공익/나눔,1)
# (선택,1)
# (SSG,1)
# (호랑이,1)
# (이,1)
# (시작,1)
# (기사보기,1)
# (카드,1)
# (�ѱ�,1)
# (1.2℃,1)
# (date,1)
# (한편의,1)
# (박신혜,1)
# (최근,1)
# (보기위해서는,1)
# (동양과,1)
# (ECB,1)
# (이전캐스트,1)
# (TV캐스트,1)
# (설치된,1)
# (구독설정,1)
# (전쟁,1)
# (7월30일,1)
# (2,1)
# (않은,1)
# (회사소개,1)
# (스포츠/연예,1)
# (Kakao,1)
# (모두투어,1)
# (따주려다,1)
# (해제,1)
# (�ַ��,1)
# (알바,1)
# (quot;FTA,1)
# (지식공간,1)
# (스탠드,1)
# (첫,1)
# (다음캐스트,1)
# (보호를,1)
# (눈,1)
# (No.1,1)
# (02:00,1)
# (copy,1)
# (최대,1)
# (11,1)
# (12,1)
# (14,1)
# (18,1)
# (모던가구기획,1)
# (���,1)
# (소호,1)
# (PC에서는,1)
# (미리보기,1)
# (in_txt,1)
# (6.8℃,1)
# (1.8℃,1)
# (알림,1)
# (Gmail,1)
# (모멸감은,1)
# (줘요,1)
# (광주,1)
# (원목,1)
# (도움말보기,1)
# (가,1)
# (경기전,1)
# (따뜻한디테일,1)
# (ㄱ-ㄹ,1)
# (327,1)
# (경기시간,1)
# (인재채용,1)
# (공감,1)
# (0순위&#39,1)
# (국어사전,1)
# (입력,1)
# (호빵을,1)
# (아름다운,1)
# (임의로,1)
# (문자,1)
# (공장,1)
# (최근검색어에서,1)
# (없어,1)
# (롯데i몰,1)
# (4위,1)
# (진짜,1)
# (천안시,1)
# (그냥,1)
# (용의자,1)
# (수족관,1)
# (�˻�,1)
# (고객님의,1)
# (번호는,1)
# (장면,1)
# (뉴스홈,1)
# (점주,1)
# (7년간,1)
# (액션,1)
# (현대,1)
# (3위,1)
# (드니프로,1)
# (뭉클한,1)
# (2.8도,1)
# (따뜻~세련,1)
# (소개,1)
# (N드라이브,1)
# (����,1)
# (설정된,1)
# (검색홈,1)
# (게임홈,1)
# (땐,1)
# (모바일,1)
# (��ް˻�,1)
# (티스토리,1)
# (검색등록,1)
# (설치하세요,1)
# (10,1)
# (느끼는,1)
# (켤,1)
# (매장정품세일,1)
# (이곳,1)
# (구독목록,1)
# (나의,1)
# (우리,1)
# (재보궐선거,1)
# (Right,1)
# (대,1)
# (음악,1)
# (서울,1)
# (영상,1)
# (신규,1)
# (웹,1)
# (있어요,1)
# (추울,1)
# (편의점,1)
# (나이,1)
# (춘천,1)
# (올해,1)
# (과학책들,1)
# (환율,1)
# (중계센터,1)
# (판매량,1)
# (마무리,1)
# (주차장인,1)
# (39;도민준&#39;의,1)
# (5.5℃,1)
# (위해,1)
# (연합뉴스,1)
# (서비스약관,1)
# (뉴스펀딩,1)
# (영어사전,1)
# (보온이빵빵,1)
# (북캐스트&nbsp,1)
# (한화,1)
# (연말,1)
# (완료,1)
# (369,1)
# (오늘의신문,1)
# (울릉도,1)
# (과학&#39,1)
# (앱스토어,1)
# (미스테리,1)
# (����Ͻ�,1)
# (주제별캐스트,1)
# (nbsp,1)
# (예쁜원피스,1)
# (소장가치100,1)
# (콘서트,1)
# (공용,1)
# (메일,1)
# (굴,1)
# (어그부츠특가,1)
# (주세요,1)
# (PC에서,1)
# (마음으로,1)
# (선거일까지,1)
# (���,1)
# (안된다는,1)
# (백과사전,1)
# (선택하여,1)
# (롯데닷컴,1)
# (약해도,1)
# (필요합니다,1)
# (각오로,1)
# (이끌어,1)
# (해,1)
# (진경에,1)
# (2위,1)
# (한글한글,1)
# (어학사전,1)
# (차이를,1)
# (불안만,1)
# (할,1)
# (66,1)
# (Play,1)
# (한,1)
# (카페명,1)
# (73.05,1)
# (활성화되었습니다,1)
# (스토리볼,1)
# (Beta,1)
# (설정,1)
# (한자사전,1)
# (동결,1)
# (연말모임룩,1)
# (급상승,1)
# (토막시신수사,1)
# (리움,1)
# (분야,1)
# (생활위젯,1)
# (연말모임패션,1)
# (아웃도어,1)
# (청주,1)
# (GS샵,1)
# (마일리지,1)
# (흐림,1)
# (꿀팁,1)
# (느끼게,1)
# (삭제한,1)
# (이용약관,1)
# (이유는,1)
# (베트남,1)
# (합니다,1)
# (물회의,1)
# (2016년,1)
# (39;느껴도,1)
# (뉴발덕다운,1)
# (쓰는,1)
# (vs,1)
# (스케일,1)
# (초월한,1)
# (클릭상품,1)
# (강릉,1)
# (티몬,1)
# (통합,1)
# (제휴제안,1)
# (까지,1)
# (해야,1)
# (자동차/테크,1)
# (이한,1)
# (쉬운,1)
# (좌우회전,1)
# (내역이,1)
# (9,1)
# (경우,1)
# (패션플러스,1)
# (대전,1)
# (권혁,1)
# (전기료,1)
# (문화&#39,1)
# (바로,1)
# (오류,1)
# (열까지,1)
# (펼치기,1)
# (발생합니다,1)
# (나그네,1)
# (베스트셀러,1)
# (ㅁ-ㅂ,1)
# (Dream,1)
# (클라우드,1)
# (말,1)
# (믿고,1)
# (����,1)
# (네이버me,1)
# (최초설치가,1)
# (호프만,1)
# (검색해,1)
# (생테티엔,1)
# (문,1)
# (quot;신인의,1)
# (사용해,1)
# (치한,1)
# (출판사,1)
# (한글,1)
# (노홍철,1)
# (오픈캐스트,1)
# (동영상,1)
# (전체보기,1)
# (������,1)
# (저장할,1)
# (웹접근성안내,1)
# (中동포,1)
# (되고,1)
# (다우,1)
# (환율전쟁과,1)
# (게,1)
# (YouTube,1)
# (패밀리,1)
# (쥬니버,1)
# (빠진,1)
# (4,1)
# (개,1)
# (위기,1)
# (것&quot,1)
# (17735.60,1)
# (해주마,1)
# (검색어로,1)
# (검색어가,1)
# (카페글,1)
# (보내기,1)
# (나스닥,1)
# (쇼핑홈,1)
# (관객이,1)
# (약관,1)
# (라인,1)
# (PC에서만,1)
# (가볍고,1)
# (이유,1)
# (51,1)
# (아우터,1)
# (가지,1)
# (자동실행,1)
# (����,1)
# (제주,1)
# (로그아웃을,1)
# (주제별,1)
# (책&nbsp,1)
# (고효율의,1)
# (쓸쓸하지만,1)
# (5위,1)
# (앞날은,1)
# (만화속세상,1)
# (한석규,1)
# (청소년보호정책,1)
# (응모,1)
# (세련된,1)
# (하나만입어도,1)
# (적응할,1)
# (테니,1)
# (단,1)
# (상반기,1)
# (10위,1)
# (시공,1)
# (2만원대,1)
# (고운맘,1)
# (상실을,1)
# (세일,1)
# (감소,1)
# (정재훈,1)
# (네이버SE,1)
# (EBS지식,1)
# (2008-2014,1)
# (검거,1)
# (금융,1)
# (846,1)
# (흔들다,1)
# (39;롯데맨&#39,1)
# (10주년,1)
# (이어온,1)
# (정복하라,1)
# (한걸음,1)
# (레고,1)
# (더예뻐졌잖아,1)
# (밥,1)
# (접근성,1)
# (or,1)
# (Best,1)
# (통합검색,1)
# (39;러버덕,1)
# (앱을,1)
# (ㅈ-ㅊ,1)
# (17,735.15,1)
# (황경신,1)
# (가히,1)
# (인터뷰,1)
# (엄마,1)
# (하는대로,1)
# (작가의,1)
# (맛있,1)
# (위해서는,1)
# (현대H몰,1)
# (김성근이,1)
# (긍정부정검색,1)
# (동화,1)
# (일본어사전,1)
# (이마트몰,1)
# (Corp,1)
# (시클라멘이란,1)
# (新풍운,1)
# (신규앱,1)
# (무료입니다,1)
# (초절전,1)
# (영영사전,1)
# (낭독,1)
# (후보에,1)
# (오빠들,1)
# (접속,1)
# (없다,1)
# (난방비,1)
# (기원은,1)
# (그,1)
# (패딩,1)
# (39;한화,1)
# (39;피노키오&#39,1)
# (eBook,1)
# (서양,1)
# (원하는대로,1)
# (어디에…사라진,1)
# (내가,1)
# (겨울,1)
# (111,1)
# (방식,1)
# (����,1)
# (��ȣ,1)
# (계십니다,1)
# (토막시신,1)
# (구매도장,1)
# (독설,1)
# (무서운,1)
# (모으다,1)
# (사용하고,1)
# (관람,1)
# (소설,1)
# (나이저,1)
# (언론사별,1)
# (오늘,1)
# (해피빈,1)
# (대만에서,1)
# (돈,1)
# (특가,1)
# (raquo,1)
# (TV,1)
# (9,900,1)
# (��,1)
# (협력문,1)
# (nbsp;나눔글꼴을,1)
# (테일즈런너,1)
# (이미지,1)
# (202.45,1)
# (인증방법,1)
# (휴대폰번호,1)
# (저장해,1)
# (100권,1)
# (18세기,1)
# (4,757.08,1)
# (매체보기,1)
# (블랙프라이데이,1)
# (마음껏,1)
# (베스트홈,1)
# (AS,1)
# (양국,1)
# (ㅅ-ㅇ,1)
# (투척,1)
# (개인정보취급방침,1)
# (미디어,1)
# (총리,1)
# (열정樂서,1)
# (��������,1)
# (임신,1)
# (투데이,1)
# (모건,1)
# (12.12,1)
# (메인에서,1)
# (3.6℃,1)
# (이렇게,1)
# (차고,1)
# most frequency words :
# 입니다
# 제목
# 링크를
# 내용을
# 확인하시려면
# 전
# 눌러주세요
# 가져오기

# %% [markdown]
# 한학기동안 좋은 강의 들려주셔서 감사합니다 교수님. 하지만 과제가 너무 어려웠어요.. 책에도 잘 설명되어있지 않고 교수님이 올려주신 자료도 간단히 나와있어서... 그래도 파이썬이라는 언어를 처음 접하게 된 기회였는데 잘 공부하면 정말 큰 도움이 될 것 같아요. 한학기동안 감사했습니다.
